# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/house_price.csv')
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %% [markdown]
# No null values present.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No duplicates present.

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df['country'].value_counts()
# Out:
# country
# USA    4600
# Name: count, dtype: int64

# %%
df['statezip'].value_counts()
# Out:
# statezip
# WA 98103    148
# WA 98052    135
# WA 98117    132
# WA 98115    130
# WA 98006    110
#            ...
# WA 98047      6
# WA 98288      3
# WA 98050      2
# WA 98354      2
# WA 98068      1
# Name: count, Length: 77, dtype: int64

# %%
df['city'].value_counts()
# Out:
# city
# Seattle                1573
# Renton                  293
# Bellevue                286
# Redmond                 235
# Kirkland                187
# Issaquah                187
# Kent                    185
# Auburn                  176
# Sammamish               175
# Federal Way             148
# Shoreline               123
# Woodinville             115
# Maple Valley             96
# Mercer Island            86
# Burien                   74
# Snoqualmie               71
# Kenmore                  66
# Des Moines               58
# North Bend               50
# Covington                43
# Duvall                   42
# Lake Forest Park         36
# Bothell                  33
# Newcastle                33
# Tukwila                  29
# SeaTac                   29
# Vashon                   29
# Enumclaw                 28
# Carnation                22
# Normandy Park            18
# Clyde Hill               11
# Fall City                11
# Medina                   11
# ...

# %%
df['street'].value_counts()
# Out:
# street
# 2520 Mulberry Walk NE    4
# 2500 Mulberry Walk NE    3
# 2803 SW Bataan St        2
# 8354 11th Ave NW         2
# 6008 8th Ave NE          2
#                         ..
# 25919 SE 37th Way        1
# 14435 SE 263rd St        1
# 2150 N 128th St          1
# 2043 NE 98th St          1
# 18923 SE 416th St        1
# Name: count, Length: 4525, dtype: int64

# %%
df['yr_renovated'].value_counts()
# Out:
# yr_renovated
# 0       2735
# 2000     170
# 2003     151
# 2009     109
# 2001     109
# 2005      95
# 2004      77
# 2014      72
# 2006      68
# 2013      61
# 1923      57
# 1994      57
# 1989      55
# 2011      54
# 2012      45
# 2008      45
# 1988      43
# 2002      41
# 1983      41
# 1999      41
# 1998      40
# 1993      39
# 1912      33
# 1992      32
# 1979      32
# 2010      30
# 1985      29
# 1997      28
# 1996      22
# 1982      22
# 1972      17
# 1990      16
# 1956      15
# 1963      12
# 1969      11
# 1984      10
# 1968       9
# 1970       9
# 1954       8
# 1945       7
# 2007       7
# 1974       6
# 1934       6
# 1958       5
# 1986       5
# 1971       5
# 1978       3
# 1955       2
# 1980       2
# 1995       2
# 1981       1
# 1953       1
# 1987       1
# 1966       1
# 1960       1
# 1948       1
# 1991       1
# 1913       1
# 1977       1
# 1975       1
# Name: count, dtype: int64

# %%
df['yr_built'].value_counts()
# Out:
# yr_built
# 2006    111
# 2005    104
# 2007     93
# 2004     92
# 1978     90
#        ...
# 1915      6
# 1935      6
# 1933      5
# 1934      4
# 1936      3
# Name: count, Length: 115, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# sqft_basement
# 0       2745
# 500       53
# 600       45
# 800       43
# 900       41
#         ...
# 1730       1
# 1870       1
# 1520       1
# 2030       1
# 1640       1
# Name: count, Length: 207, dtype: int64

# %%
df['sqft_above'].value_counts()
# Out:
# sqft_above
# 1010    47
# 1200    47
# 1300    45
# 1140    44
# 1320    43
#         ..
# 3910     1
# 3831     1
# 1954     1
# 8020     1
# 2538     1
# Name: count, Length: 511, dtype: int64

# %%
df['condition'].value_counts()
# Out:
# condition
# 3    2875
# 4    1252
# 5     435
# 2      32
# 1       6
# Name: count, dtype: int64

# %%
df['view'].value_counts()
# Out:
# view
# 0    4140
# 2     205
# 3     116
# 4      70
# 1      69
# Name: count, dtype: int64

# %%
df['waterfront'].value_counts()
# Out:
# waterfront
# 0    4567
# 1      33
# Name: count, dtype: int64

# %%
df['floors'].value_counts()
# Out:
# floors
# 1.0    2174
# 2.0    1811
# 1.5     444
# 3.0     128
# 2.5      41
# 3.5       2
# Name: count, dtype: int64

# %%
df['sqft_lot'].value_counts()
# Out:
# sqft_lot
# 5000     80
# 6000     65
# 4000     54
# 7200     50
# 4800     29
#          ..
# 3690      1
# 92347     1
# 20349     1
# 9906      1
# 5405      1
# Name: count, Length: 3113, dtype: int64

# %%
df['sqft_living'].value_counts()
# Out:
# sqft_living
# 1940    32
# 1720    32
# 1840    31
# 1660    31
# 2000    30
#         ..
# 6980     1
# 4960     1
# 5700     1
# 4240     1
# 5300     1
# Name: count, Length: 566, dtype: int64

# %%
df['bathrooms'].value_counts()
# Out:
# bathrooms
# 2.50    1189
# 1.00     743
# 1.75     629
# 2.00     427
# 2.25     419
# 1.50     291
# 2.75     276
# 3.00     167
# 3.50     162
# 3.25     136
# 3.75      37
# 4.50      29
# 4.00      23
# 4.25      23
# 0.75      17
# 4.75       7
# 5.00       6
# 5.25       4
# 5.50       4
# 1.25       3
# 0.00       2
# 6.25       2
# 5.75       1
# 8.00       1
# 6.50       1
# 6.75       1
# Name: count, dtype: int64

# %%
df['bedrooms'].value_counts()
# Out:
# bedrooms
# 3.0    2032
# 4.0    1531
# 2.0     566
# 5.0     353
# 6.0      61
# 1.0      38
# 7.0      14
# 8.0       2
# 0.0       2
# 9.0       1
# Name: count, dtype: int64

# %%
df['price'].value_counts()
# Out:
# price
# 0.000000         49
# 300000.000000    42
# 400000.000000    31
# 600000.000000    29
# 450000.000000    29
#                  ..
# 691000.000000     1
# 282766.666667     1
# 406062.500000     1
# 473200.000000     1
# 454790.000000     1
# Name: count, Length: 1741, dtype: int64

# %%
df['date'].value_counts()
# Out:
# date
# 2014-06-23 00:00:00    142
# 2014-06-25 00:00:00    131
# 2014-06-26 00:00:00    131
# 2014-07-08 00:00:00    127
# 2014-07-09 00:00:00    121
#                       ...
# 2014-06-07 00:00:00      4
# 2014-07-06 00:00:00      3
# 2014-05-11 00:00:00      2
# 2014-07-04 00:00:00      2
# 2014-05-17 00:00:00      1
# Name: count, Length: 70, dtype: int64

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %% [markdown]
# # **UNIVARIATE ANALYSIS**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
plt.figure()
df['city'].hist(bins=5)
plt.xlabel('city')
plt.ylabel('frequency')
plt.title('Histogram Of city')
plt.show()
df['city'].describe()
# Out:
# count        4600
# unique         44
# top       Seattle
# freq         1573
# Name: city, dtype: object

# %%
plt.figure()
df['street'].hist(bins=5)
plt.xlabel('street')
plt.ylabel('frequency')
plt.title('Histogram Of street')
plt.show()
df['street'].describe()
# Out:
# count                      4600
# unique                     4525
# top       2520 Mulberry Walk NE
# freq                          4
# Name: street, dtype: object

# %%
plt.figure()
df['statezip'].hist(bins=5)
plt.xlabel('statezip')
plt.ylabel('frequency')
plt.title('Histogram Of statezip')
plt.show()
df['statezip'].describe()
# Out:
# count         4600
# unique          77
# top       WA 98103
# freq           148
# Name: statezip, dtype: object

# %%
plt.figure()
df['country'].hist(bins=5)
plt.xlabel('country')
plt.ylabel('frequency')
plt.title('Histogram Of country')
plt.show()
df['country'].describe()
# Out:
# count     4600
# unique       1
# top        USA
# freq      4600
# Name: country, dtype: object

# %%
plt.figure()
df['yr_renovated'].hist(bins=5)
plt.xlabel('yr_renovated')
plt.ylabel('frequency')
plt.title('Histogram Of yr_renovated')
plt.show()
df['yr_renovated'].describe()
# Out:
# count    4600.000000
# mean      808.608261
# std       979.414536
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%      1999.000000
# max      2014.000000
# Name: yr_renovated, dtype: float64

# %%
plt.figure()
df['yr_built'].hist(bins=5)
plt.xlabel('yr_built')
plt.ylabel('frequency')
plt.title('Histogram Of yr_built')
plt.show()
df['yr_built'].describe()
# Out:
# count    4600.000000
# mean     1970.786304
# std        29.731848
# min      1900.000000
# 25%      1951.000000
# 50%      1976.000000
# 75%      1997.000000
# max      2014.000000
# Name: yr_built, dtype: float64

# %%
plt.figure()
df['sqft_basement'].hist(bins=5)
plt.xlabel('sqft_basement')
plt.ylabel('frequency')
plt.title('Histogram Of sqft_basement')
plt.show()
df['sqft_basement'].describe()
# Out:
# count    4600.000000
# mean      312.081522
# std       464.137228
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       610.000000
# max      4820.000000
# Name: sqft_basement, dtype: float64

# %%
plt.figure()
df['sqft_above'].hist(bins=5)
plt.xlabel('sqft_above')
plt.ylabel('frequency')
plt.title('Histogram Of sqft_above')
plt.show()
df['sqft_above'].describe()
#
# Out:
# count    4600.000000
# mean     1827.265435
# std       862.168977
# min       370.000000
# 25%      1190.000000
# 50%      1590.000000
# 75%      2300.000000
# max      9410.000000
# Name: sqft_above, dtype: float64

# %%
plt.figure()
df['condition'].hist(bins=5)
plt.xlabel('condition')
plt.ylabel('frequency')
plt.title('Histogram Of condition')
plt.show()
df['condition'].describe()
# Out:
# count    4600.000000
# mean        3.451739
# std         0.677230
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: condition, dtype: float64

# %%
plt.figure()
df['view'].hist(bins=5)
plt.xlabel('view')
plt.ylabel('frequency')
plt.title('Histogram Of view')
plt.show()
df['view'].describe()
# Out:
# count    4600.000000
# mean        0.240652
# std         0.778405
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         4.000000
# Name: view, dtype: float64

# %%
plt.figure()
df['waterfront'].hist(bins=5)
plt.xlabel('waterfront')
plt.ylabel('Frequency')
plt.title('Histogram Of waterfront')
plt.show()
df['waterfront'].describe()
# Out:
# count    4600.000000
# mean        0.007174
# std         0.084404
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: waterfront, dtype: float64

# %%
plt.figure()
df['floors'].hist(bins=5)
plt.xlabel('floors')
plt.ylabel('Frequency')
plt.title('Histogram Of floors')
plt.show()
df['floors'].describe()
# Out:
# count    4600.000000
# mean        1.512065
# std         0.538288
# min         1.000000
# 25%         1.000000
# 50%         1.500000
# 75%         2.000000
# max         3.500000
# Name: floors, dtype: float64

# %%
plt.figure()
df['sqft_lot'].hist(bins=5)
plt.xlabel('sqft_lot')
plt.ylabel('Frequency')
plt.title('Histogram Of sqft_lot')
plt.show()
df['sqft_lot'].describe()
# Out:
# count    4.600000e+03
# mean     1.485252e+04
# std      3.588444e+04
# min      6.380000e+02
# 25%      5.000750e+03
# 50%      7.683000e+03
# 75%      1.100125e+04
# max      1.074218e+06
# Name: sqft_lot, dtype: float64

# %%
plt.figure()
df['sqft_living'].hist(bins=5)
plt.xlabel('sqft_living')
plt.ylabel('Frequency')
plt.title('Histogram Of sqft_living')
plt.show()
df['sqft_living'].describe()
# Out:
# count     4600.000000
# mean      2139.346957
# std        963.206916
# min        370.000000
# 25%       1460.000000
# 50%       1980.000000
# 75%       2620.000000
# max      13540.000000
# Name: sqft_living, dtype: float64

# %%
plt.figure()
df['bathrooms'].hist(bins=5)
plt.xlabel('bathrooms')
plt.ylabel('Frequency')
plt.title('Histogram Of bathrooms')
plt.show()
df['bathrooms'].describe()
# Out:
# count    4600.000000
# mean        2.160815
# std         0.783781
# min         0.000000
# 25%         1.750000
# 50%         2.250000
# 75%         2.500000
# max         8.000000
# Name: bathrooms, dtype: float64

# %%
plt.figure()
df['bedrooms'].hist(bins=5)
plt.xlabel('bedrooms')
plt.ylabel('Frequency')
plt.title('Histogram Of bedrooms')
plt.show()
df['bedrooms'].describe()
# Out:
# count    4600.000000
# mean        3.400870
# std         0.908848
# min         0.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         9.000000
# Name: bedrooms, dtype: float64

# %%
plt.figure(figsize=(6,4))
df['price'].hist(bins=5)
plt.xlabel('price')
plt.ylabel('Frequency')
plt.title('Histogram Of price')
plt.show()
df['price'].describe()
# Out:
# count    4.600000e+03
# mean     5.519630e+05
# std      5.638347e+05
# min      0.000000e+00
# 25%      3.228750e+05
# 50%      4.609435e+05
# 75%      6.549625e+05
# max      2.659000e+07
# Name: price, dtype: float64

# %% [markdown]
# # **BI-VARIATE ANALYSIS**

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df['price'],y=df['bedrooms'])
plt.xlabel('price')
plt.ylabel('bedrooms')
plt.title('Box Plot Of sprice Vs bedrooms')
plt.show()

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df['price'],y=df['bathrooms'])
plt.xlabel('price')
plt.ylabel('bathrooms')
plt.title('Box Plot Of price Vs bathrooms')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df['price'],y=df['sqft_living'])
plt.xlabel('price')
plt.ylabel('sqft_living')
plt.title('Box Plot Of price Vs sqft_living')
plt.show()

# %%
sns.scatterplot(x=df['price'],y=df['sqft_lot'])
plt.xlabel('price')
plt.ylabel('sqft_lot')
plt.title('Box Plot Of price Vs sqft_lot')
plt.show()

# %%
sns.scatterplot(x=df['price'],y=df['floors'])
plt.xlabel('price')
plt.ylabel('floors')
plt.title('Box Plot Of price Vs floors')
plt.show()

# %%
sns.scatterplot(x=df['price'],y=df['waterfront'])
plt.xlabel('price')
plt.ylabel('waterfront')
plt.title('Box Plot Of price Vs waterfront')
plt.show()

# %%
sns.scatterplot(x=df['price'],y=df['view'])
plt.xlabel('price')
plt.ylabel('view')
plt.title('Box Plot Of price Vs view')
plt.show()

# %%
sns.scatterplot(x=df['price'],y=df['condition'])
plt.xlabel('price')
plt.ylabel('condition')
plt.title('Box Plot Of price Vs condition')
plt.show()

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
sns.scatterplot(x=df['price'],y=df['yr_built'])
plt.xlabel('price')
plt.ylabel('yr_built')
plt.title('Box Plot Of price Vs yr_built')
plt.show()

# %%
sns.scatterplot(x=df['price'],y=df['yr_renovated'])
plt.xlabel('price')
plt.ylabel('yr_renovated')
plt.title('Box Plot Of price Vs yr_renovated')
plt.show()

# %%
sns.scatterplot(x=df['city'],y=df['price'])
plt.xlabel('city')
plt.ylabel('price')
plt.xticks(rotation=90)
plt.title('Box Plot Of price Vs city')
plt.show()

# %% [markdown]
# # **MULTI-VARIATE ANALYSIS**

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
sns.barplot(x=df['bedrooms'],y=df['bathrooms'],hue=df['price'])
plt.xlabel('bedrooms')
plt.ylabel('bathrooms')
plt.title('Scatter Plot Of bedrooms Vs bathrooms')
plt.show()

# %%
sns.barplot(x=df['sqft_living'],y=df['yr_built'],hue=df['price'])
plt.xlabel('sqft_living')
plt.ylabel('yr_built')
plt.title('Scatter Plot Of sqft_living Vs yr_built')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.barplot(x=df['sqft_lot'],y=df['floors'],hue=df['price'])
plt.xlabel('sqft_lot')
plt.ylabel('floors')
plt.title('Scatter Plot Of sqft_lot Vs floors')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.barplot(x=df['waterfront'],y=df['view'],hue=df['price'])
plt.xlabel('waterfront')
plt.ylabel('view')
plt.title('Scatter Plot Of waterfront Vs view')
plt.show()

# %%
sns.barplot(x=df['condition'],y=df['sqft_above'],hue=df['price'])
plt.xlabel('condition')
plt.ylabel('sqft_above')
plt.title('Scatter Plot Of condition Vs sqft_above')
plt.show()

# %% [markdown]
# # **OUTLIER HANDLING**

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
sns.boxplot(data=df,x='date')
plt.title('Box Plot Of date')
plt.show()

# %%
sns.boxplot(data=df,x='price')
plt.title('Box Plot Of price')
plt.show()

# %%
  Q1=df['price'].quantile(0.25)
  Q3=df['price'].quantile(0.75)
  IQR=Q3-Q1
  lower_limit=Q1-1.5*IQR
  upper_limit=Q3+1.5*IQR
  df['price']=np.where(df['price']>upper_limit,upper_limit,np.where (df['price']<lower_limit,lower_limit,df['price']))

# %%
sns.boxplot(data=df,x='price')
plt.title('Box Plot Of price')
plt.show()

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
sns.boxplot(data=df,x='bedrooms')
plt.title('Box Plot Of bedrooms')
plt.show()

# %%
  Q1=df['bedrooms'].quantile(0.25)
  Q3=df['bedrooms'].quantile(0.75)
  IQR=Q3-Q1
  lower_limit=Q1-1.5*IQR
  upper_limit=Q3+1.5*IQR
  df['bedrooms']=np.where(df['bedrooms']>upper_limit,upper_limit,np.where (df['bedrooms']<lower_limit,lower_limit,df['bedrooms']))

# %%
sns.boxplot(data=df,x='bedrooms')
plt.title('Box Plot Of bedrooms')
plt.show()

# %%
sns.boxplot(data=df,x='bathrooms')
plt.title('Box Plot Of bathrooms')
plt.show()

# %%
  Q1=df['bathrooms'].quantile(0.25)
  Q3=df['bathrooms'].quantile(0.75)
  IQR=Q3-Q1
  lower_limit=Q1-1.5*IQR
  upper_limit=Q3+1.5*IQR
  df['bathrooms']=np.where(df['bathrooms']>upper_limit,upper_limit,np.where (df['bathrooms']<lower_limit,lower_limit,df['bathrooms']))

# %%
sns.boxplot(data=df,x='bathrooms')
plt.title('Box Plot Of bathrooms')
plt.show()

# %%
sns.boxplot(data=df,x='sqft_living')
plt.title('Box Plot Of sqft_living')
plt.show()

# %%
  Q1=df['sqft_living'].quantile(0.25)
  Q3=df['sqft_living'].quantile(0.75)
  IQR=Q3-Q1
  lower_limit=Q1-1.5*IQR
  upper_limit=Q3+1.5*IQR
  df['sqft_living']=np.where(df['sqft_living']>upper_limit,upper_limit,np.where (df['sqft_living']<lower_limit,lower_limit,df['sqft_living']))

# %%
sns.boxplot(data=df,x='sqft_living')
plt.title('Box Plot Of sqft_living')
plt.show()

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
sns.boxplot(data=df,x='sqft_lot')
plt.title('Box Plot Of sqft_lot')
plt.show()

# %%
  Q1=df['sqft_lot'].quantile(0.25)
  Q3=df['sqft_lot'].quantile(0.75)
  IQR=Q3-Q1
  lower_limit=Q1-1.5*IQR
  upper_limit=Q3+1.5*IQR
  df['sqft_lot']=np.where(df['sqft_lot']>upper_limit,upper_limit,np.where (df['sqft_lot']<lower_limit,lower_limit,df['sqft_lot']))

# %%
sns.boxplot(data=df,x='sqft_lot')
plt.title('Box Plot Of sqft_lot')
plt.show()

# %%
sns.boxplot(data=df,x='floors')
plt.title('Box Plot Of floors')
plt.show()

# %%
  Q1=df['floors'].quantile(0.25)
  Q3=df['floors'].quantile(0.75)
  IQR=Q3-Q1
  lower_limit=Q1-1.5*IQR
  upper_limit=Q3+1.5*IQR
  df['floors']=np.where(df['floors']>upper_limit,upper_limit,np.where (df['floors']<lower_limit,lower_limit,df['floors']))

# %%
sns.boxplot(data=df,x='floors')
plt.title('Box Plot Of floors')
plt.show()

# %%
df.columns

# %%
sns.boxplot(data=df,x='waterfront')
plt.title('Box Plot Of waterfront')
plt.show()

# %%
sns.boxplot(data=df,x='view')
plt.title('Box Plot Of view')
plt.show()

# %%
  Q1=df['view'].quantile(0.25)
  Q3=df['view'].quantile(0.75)
  IQR=Q3-Q1
  lower_limit=Q1-1.5*IQR
  upper_limit=Q3+1.5*IQR
  df['view']=np.where(df['view']>upper_limit,upper_limit,np.where (df['view']<lower_limit,lower_limit,df['view']))

# %%
sns.boxplot(data=df,x='view')
plt.title('Box Plot Of view')
plt.show()

# %%
sns.boxplot(data=df,x='condition')
plt.title('Box Plot Of condition')
plt.show()

# %%
df.columns

# %%
sns.boxplot(data=df,x='sqft_above')
plt.title('Box Plot Of sqft_above')
plt.show()

# %%
  Q1=df['sqft_above'].quantile(0.25)
  Q3=df['sqft_above'].quantile(0.75)
  IQR=Q3-Q1
  lower_limit=Q1-1.5*IQR
  upper_limit=Q3+1.5*IQR
  df['sqft_above']=np.where(df['sqft_above']>upper_limit,upper_limit,np.where (df['sqft_above']<lower_limit,lower_limit,df['sqft_above']))

# %%
sns.boxplot(data=df,x='sqft_above')
plt.title('Box Plot Of sqft_above')
plt.show()

# %%
sns.boxplot(data=df,x='sqft_basement')
plt.title('Box Plot Of sqft_basement')
plt.show()

# %%
  Q1=df['sqft_basement'].quantile(0.25)
  Q3=df['sqft_basement'].quantile(0.75)
  IQR=Q3-Q1
  lower_limit=Q1-1.5*IQR
  upper_limit=Q3+1.5*IQR
  df['sqft_basement']=np.where(df['sqft_basement']>upper_limit,upper_limit,np.where (df['sqft_basement']<lower_limit,lower_limit,df['sqft_basement']))

# %%
sns.boxplot(data=df,x='sqft_basement')
plt.title('Box Plot Of sqft_basement')
plt.show()

# %%
sns.boxplot(data=df,x='yr_built')
plt.title('Box Plot Of yr_built')
plt.show()

# %%
df.columns

# %%
sns.boxplot(data=df,x='yr_renovated')
plt.title('Box Plot Of yr_renovated')
plt.show()

# %%
sns.boxplot(data=df,x='street')
plt.title('Box Plot Of street')
plt.show()

# %%
sns.boxplot(data=df,x='statezip')
plt.title('Box Plot Of statezip')
plt.show()

# %%
sns.boxplot(data=df,x='country')
plt.title('Box Plot Of country')
plt.show()

# %% [markdown]
# # **TYPE CONVERSION**

# %%
df.columns

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['date_numeric'] = df['date'].astype('int64')

# %% [markdown]
# # **ENCODING**

# %% [markdown]
# (a) Label Encoding

# %%
df.head()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
en=LabelEncoder()

# %%
df['country']=en.fit_transform(df['country'])
print(en.classes_)

# %%
df['waterfront']=en.fit_transform(df['waterfront'])
print(en.classes_)

# %%
df['view']=en.fit_transform(df['view'])
print(en.classes_)

# %%
df['condition']=en.fit_transform(df['condition'])
print(en.classes_)

# %%
df['floors']=en.fit_transform(df['floors'])
print(en.classes_)

# %% [markdown]
# (b) Target Encoding

# %%
pip install category_encoders
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 kB 3.4 MB/s eta 0:00:00
# ...

# %%
from category_encoders import TargetEncoder

# %%
en_tar=TargetEncoder()

# %%
df['street']=en_tar.fit_transform(df['street'],df['price'])

# %%
df['city']=en_tar.fit_transform(df['city'],df['price'])

# %%
df['date']=en_tar.fit_transform(df['date'],df['price'])

# %%
sns.boxplot(data=df,x='city')
plt.title('Box Plot Of city')
plt.show()

# %%
  Q1=df['city'].quantile(0.25)
  Q3=df['city'].quantile(0.75)
  IQR=Q3-Q1
  lower_limit=Q1-1.5*IQR
  upper_limit=Q3+1.5*IQR
  df['city']=np.where(df['city']>upper_limit,upper_limit,np.where (df['city']<lower_limit,lower_limit,df['city']))

# %%
sns.boxplot(data=df,x='city')
plt.title('Box Plot Of city')
plt.show()

# %%
df['statezip']=en_tar.fit_transform(df['statezip'],df['price'])

# %% [markdown]
# # **CORRELATION**

# %%
df.corr()
# Out:
#                    date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date           1.000000  0.028642  0.008314   0.021893     0.032014  0.010200
# price          0.028642  1.000000  0.336636   0.504113     0.663015  0.155890
# bedrooms       0.008314  0.336636  1.000000   0.542420     0.619916  0.213088
# bathrooms      0.021893  0.504113  0.542420   1.000000     0.748138  0.133726
# sqft_living    0.032014  0.663015  0.619916   0.748138     1.000000  0.369314
# sqft_lot       0.010200  0.155890  0.213088   0.133726     0.369314  1.000000
# floors         0.029607  0.289390  0.181811   0.505157     0.357140 -0.161186
# waterfront     0.017586  0.108123 -0.004377   0.052406     0.087381  0.112785
# view                NaN       NaN       NaN        NaN          NaN       NaN
# condition      0.007853  0.049187  0.022727  -0.123672    -0.061743  0.041942
# sqft_above     0.040867  0.572611  0.501552   0.674544     0.868918  0.351269
# ...

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
cor_df=["date","sqft_living","sqft_above","city","price"]

# %%
cor_ddf=df[cor_df]
cor_ddf
# Out:
#            date  sqft_living  sqft_above           city         price
# 0    2014-05-02       1340.0      1340.0  408738.992779  3.130000e+05
# 1    2014-05-02       3650.0      3370.0  546389.589554  1.153094e+06
# 2    2014-05-02       1930.0      1930.0  301995.668783  3.420000e+05
# 3    2014-05-02       2000.0      1000.0  750418.528554  4.200000e+05
# 4    2014-05-02       1940.0      1140.0  657539.330461  5.500000e+05
# ...         ...          ...         ...            ...           ...
# 4595 2014-07-09       1510.0      1510.0  546389.589554  3.081667e+05
# 4596 2014-07-09       1460.0      1460.0  750418.528554  5.343333e+05
# 4597 2014-07-09       3010.0      3010.0  377040.966329  4.169042e+05
# 4598 2014-07-10       2090.0      1070.0  546389.589554  2.034000e+05
# 4599 2014-07-10       1490.0      1490.0  294220.964565  2.206000e+05
#
# [4600 rows x 5 columns]

# %%
plt.figure(figsize=(14,7))
sns.heatmap(cor_ddf.corr(),annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # **SPLITTING DATASET**

# %%
from sklearn.model_selection import train_test_split

# %%
x=cor_ddf.drop('price',axis=1)
y=cor_ddf['price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#            date  sqft_living  sqft_above           city
# 1898 2014-06-04       2770.0      2770.0  603185.363584
# 1370 2014-05-27       3720.0      3720.0  618634.822859
# 3038 2014-06-23       2810.0      2810.0  673145.947417
# 2361 2014-06-12       4030.0      3965.0  618634.822859
# 156  2014-05-06       2000.0      2000.0  546389.589554
# ...         ...          ...         ...            ...
# 4426 2014-05-28       1180.0      1180.0  408738.992779
# 466  2014-05-10       2520.0      1400.0  546389.589554
# 3092 2014-06-23       1150.0       990.0  408738.992779
# 3772 2014-07-01        910.0       910.0  546389.589554
# 860  2014-05-19       1490.0       860.0  546389.589554
#
# [3680 rows x 4 columns]

# %%
y_train
# Out:
# 1898    6.850000e+05
# 1370    8.570000e+05
# 3038    6.750000e+05
# 2361    1.153094e+06
# 156     5.610000e+05
#             ...
# 4426    2.825089e+05
# 466     8.750000e+05
# 3092    2.900000e+05
# 3772    6.000000e+05
# 860     4.750000e+05
# Name: price, Length: 3680, dtype: float64

# %%
x_test
# Out:
#            date  sqft_living  sqft_above           city
# 3683 2014-06-30       1460.0      1180.0  546389.589554
# 4411 2014-05-22       2000.0      1300.0  323826.416797
# 2584 2014-06-16       2940.0      2440.0  546389.589554
# 69   2014-05-04       2200.0      1570.0  377040.966329
# 1844 2014-06-04       1720.0      1000.0  289888.330975
# ...         ...          ...         ...            ...
# 1612 2014-05-30       1700.0      1460.0  546389.589554
# 1068 2014-05-21       1930.0      1930.0  546389.589554
# 4350 2014-07-03       1180.0      1180.0  301995.668783
# 3027 2014-06-22       2370.0      2370.0  618634.822859
# 3455 2014-06-26       2260.0      2260.0  301995.668783
#
# [920 rows x 4 columns]

# %%
y_test
# Out:
# 3683     544000.00
# 4411          0.00
# 2584    1153093.75
# 69       365000.00
# 1844     275000.00
#            ...
# 1612     750000.00
# 1068     230000.00
# 4350    1153093.75
# 3027     687000.00
# 3455     289659.00
# Name: price, Length: 920, dtype: float64

# %%
x_train.shape
# Out:
# (3680, 4)

# %%
y_train.shape
# Out:
# (3680,)

# %% [markdown]
# # **SCALING**

# %% [markdown]
# (a) Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
# Drop the date column before scaling
x_train_std = scaler.fit_transform(x_train.drop('date', axis=1))
x_test_std= scaler.transform(x_test.drop('date', axis=1))

# %%
x_train_std
# Out:
# array([[ 0.75478258,  1.20204624,  0.61327378],
#        [ 1.84527401,  2.38517127,  0.72552174],
#        [ 0.80069801,  1.25186203,  1.12157201],
#        ...,
#        [-1.10479227, -1.01475646, -0.79947524],
#        [-1.38028484, -1.11438804,  0.2006244 ],
#        [-0.71451113, -1.17665778,  0.2006244 ]])

# %%
x_test_std
# Out:
# array([[-0.7489477 , -0.77813145,  0.2006244 ],
#        [-0.12908942, -0.62868408, -1.41640708],
#        [ 0.94992315,  0.79106596,  0.2006244 ],
#        ...,
#        [-1.0703557 , -0.77813145, -1.57501826],
#        [ 0.2956283 ,  0.70388833,  0.72552174],
#        [ 0.16936087,  0.5668949 , -1.57501826]])

# %% [markdown]
# (b)Min-Max Scalar

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mscaler=MinMaxScaler()

# %%
# Drop the date column before scaling
x_train_min = mscaler.fit_transform(x_train.drop('date', axis=1))
x_test_min = mscaler.transform(x_test.drop('date', axis=1))

# %%
x_train_min
# Out:
# array([[0.60150376, 0.66759388, 0.51828876],
#        [0.839599  , 0.93184979, 0.54384688],
#        [0.61152882, 0.67872045, 0.63402489],
#        ...,
#        [0.19548872, 0.17246175, 0.19661521],
#        [0.13533835, 0.15020862, 0.42433125],
#        [0.28070175, 0.13630042, 0.42433125]])

# %%
x_test_min
# Out:
# array([[0.27318296, 0.22531293, 0.42433125],
#        [0.4085213 , 0.25869263, 0.05614394],
#        [0.64411028, 0.57579972, 0.42433125],
#        ...,
#        [0.20300752, 0.22531293, 0.02002923],
#        [0.50125313, 0.55632823, 0.54384688],
#        [0.47368421, 0.52573018, 0.02002923]])

# %% [markdown]
# # **MODEL BUILDING**

# %% [markdown]
# # **Hyperparameter Tuning**

# %%
# Step 1: Import required libraries
# from sklearn.datasets import load_diabetes
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.metrics import r2_score



# Step 3: Define models
models = {
    'KNN Regressor': KNeighborsRegressor(),
    'Linear Regression': LinearRegression(),
    'Decision Tree Regressor': DecisionTreeRegressor(random_state=42),
    'Random Forest Regressor': RandomForestRegressor(random_state=42),
    'AdaBoost Regressor': AdaBoostRegressor(random_state=42)
}

# Step 4: Define parameter grids for each model
param_grids = {
    'KNN Regressor': {
        'n_neighbors': [3, 5, 7, 9],
        'weights': ['uniform', 'distance'],
        'p': [1, 2]
    },
    'Linear Regression': {
        'fit_intercept': [True, False],
        'copy_X': [True, False]
    },
    'Decision Tree Regressor': {
        'criterion': ['squared_error', 'friedman_mse'],
        'max_depth': [None, 5, 10, 20],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    },
    'Random Forest Regressor': {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'bootstrap': [True, False]
    },
    'AdaBoost Regressor': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 1.0]
    }
}

# Step 5: Perform Grid Search for each model
best_models = {}

for name, model in models.items():
    print(f"\n🔍 Tuning {name}...")

    grid = GridSearchCV(
        estimator=model,
        param_grid=param_grids[name],
        cv=5,
        scoring='r2',
        n_jobs=-1
    )

    grid.fit(x_train_min,y_train)
    best_models[name] = grid.best_estimator_

    print(f"✅ Best Parameters for {name}: {grid.best_params_}")
    print(f"🏆 Best R² Score (CV): {grid.best_score_:.4f}")

# Step 6: Evaluate the best models on test data
print("\n📊 Final Model Performance on Test Set:")
for name, model in best_models.items():
    y_pred = model.predict(x_test)
    print(f"{name}: R² Score = {r2_score(y_test, y_pred):.4f}")
# Out:
# 🔍 Tuning KNN Regressor...
# ✅ Best Parameters for KNN Regressor: {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 🏆 Best R² Score (CV): 0.6201
#
# 🔍 Tuning Linear Regression...
# ✅ Best Parameters for Linear Regression: {'copy_X': True, 'fit_intercept': True}
# 🏆 Best R² Score (CV): 0.6142
#
# 🔍 Tuning Decision Tree Regressor...
# ✅ Best Parameters for Decision Tree Regressor: {'criterion': 'squared_error', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 🏆 Best R² Score (CV): 0.6293
#
# 🔍 Tuning Random Forest Regressor...
# ✅ Best Parameters for Random Forest Regressor: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# 🏆 Best R² Score (CV): 0.6486
#
# 🔍 Tuning AdaBoost Regressor...
# ✅ Best Parameters for AdaBoost Regressor: {'learning_rate': 0.01, 'n_estimators': 100}
# 🏆 Best R² Score (CV): 0.6066
#
# 📊 Final Model Performance on Test Set:
# ...

# %% [markdown]
# # **KNN**

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knnr=KNeighborsRegressor()

# %%
knnr.fit(x_train_min,y_train)

# %%
knnr.score(x_train_min,y_train)

# %%
knnr.score(x_test_min,y_test)

# %%
y_pred_knnr=knnr.predict(x_test_min)

# %%
y_pred_knnr

# %%
result_knn=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_knnr})
result_knn

# %%
sns.lineplot(data=result_knn)
plt.title('KNN')
plt.show()

# %% [markdown]
# # **KNN MODEL EVALUATION**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
knn_mse=mean_squared_error(y_test,y_pred_knnr)
knn_mse

# %%
knn_r2=r2_score(y_test,y_pred_knnr)
knn_r2

# %%
knn_mae=mean_absolute_error(y_test,y_pred_knnr)
knn_mae

# %%
knn_rmse=np.sqrt(knn_mse)
knn_rmse

# %% [markdown]
# No need to execute types of classification metrics since this dataset have a numerical target(i.e. it is a numerical dataset.)

# %% [markdown]
# # **LINEAR REGRESSION MODEL**

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train_std,y_train)

# %%
lr.score(x_train_std,y_train)

# %%
lr.score(x_test_std,y_test)

# %%
y_pred_lr=lr.predict(x_test_std)

# %%
y_pred_lr

# %%
result_lr=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_lr})
result_lr

# %%
sns.lineplot(data=result_lr)
plt.title('KNN')
plt.show()

# %% [markdown]
# # **Linear Regression Model Evaluation**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
lr_mse=mean_squared_error(y_test,y_pred_lr)
lr_mse

# %%
lr_r2=r2_score(y_test,y_pred_lr)
lr_r2

# %%
lr_mae=mean_absolute_error(y_test,y_pred_lr)
lr_mae

# %%
lr_rmse=np.sqrt(lr_mse)
lr_rmse

# %% [markdown]
# # **DECISION TREE ALGORITHM**

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
deci=DecisionTreeRegressor()

# %%
deci.fit(x_train_std,y_train)

# %%
deci.score(x_train_std,y_train)

# %%
deci.score(x_test_std,y_test)

# %%
y_pred_deci=deci.predict(x_test_std)
y_pred_deci

# %%
result_deci=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_deci})
result_deci

# %% [markdown]
# # **DECISION TREE MODEL EVALUATION**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
deci_mse=mean_squared_error(y_test,y_pred_deci)
deci_mse

# %%
deci_rmse=np.sqrt(deci_mse)
deci_rmse

# %%
deci_r2=r2_score(y_test,y_pred_deci)
deci_r2

# %%
deci_mae=mean_absolute_error(y_test,y_pred_deci)
deci_mae

# %% [markdown]
# # **RANDOM FOREST MODEL**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rand=RandomForestRegressor(n_estimators=49,max_depth=5)

# %%
# rand=RandomForestRegressor(n_estimators=50,max_depth=10,random_state=42)

# %%
rand.fit(x_train_std,y_train)

# %%
rand.score(x_train_std,y_train)

# %%
rand.score(x_test_std,y_test)

# %%
y_pred_rand=rand.predict(x_test_std)
y_pred_rand

# %%
result_rand=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_rand})
result_rand

# %% [markdown]
# # **RANDOM FOREST MODEL EVALUATION**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
rand_mse=mean_squared_error(y_test,y_pred_rand)
rand_mse

# %%
rand_rmse=np.sqrt(rand_mse)
rand_rmse

# %%
rand_r2=r2_score(y_test,y_pred_rand)
rand_r2

# %%
rand_mae=mean_absolute_error(y_test,y_pred_rand)
rand_mae

# %% [markdown]
# # **BOOSTING MODEL**

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
base_model=DecisionTreeRegressor(max_depth=5)
boost=AdaBoostRegressor(estimator=base_model,n_estimators=100,learning_rate=0.1,random_state=42)

# %%
boost.fit(x_train_std,y_train)

# %%
boost.score(x_train_std,y_train)

# %%
boost.score(x_test_std,y_test)

# %%
y_pred_boost=boost.predict(x_test_std)
y_pred_boost

# %%
result_boost=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_boost})
result_boost

# %% [markdown]
# # **BOOSTING MODEL EVALUATION**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
boost_mse=mean_squared_error(y_test,y_pred_boost)
boost_mse

# %%
boost_rmse=np.sqrt(boost_mse)
boost_rmse

# %%
boost_r2=r2_score(y_test,y_pred_boost)
boost_r2

# %%
boost_mae=mean_absolute_error(y_test,y_pred_boost)
boost_mae

# %% [markdown]
# # **STACKING ALGORITHM MODEL**

# %%
from sklearn.ensemble import StackingRegressor

# %%
st=StackingRegressor(estimators=[('knn',knnr),('lr',lr),('deci',deci),('rand',rand),('boost',boost)],final_estimator=LinearRegression())

# %%
st.fit(x_train_std,y_train)

# %%
st.score(x_train_std,y_train)

# %%
st.score(x_test_std,y_test)

# %%
y_pred_st=st.predict(x_test_std)
y_pred_st

# %%
result_st=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_st})
result_st

# %% [markdown]
# # **STACKING MODEL EVALUATION**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
st_mse=mean_squared_error(y_test,y_pred_st)
st_mse

# %%
st_rmse=np.sqrt(st_mse)
st_rmse

# %%
st_r2=r2_score(y_test,y_pred_st)
st_r2

# %%
st_mae=mean_absolute_error(y_test,y_pred_st)
st_mae

# %% [markdown]
# # **SVM ALGORITHM**

# %%
from sklearn.svm import SVR

# %%
svm_reg=SVR(kernel='linear',C=1.0,epsilon=0.1)

# %%
svm_reg.fit(x_train_std,y_train)

# %%
svm_reg.score(x_train_std,y_train)

# %%
svm_reg.score(x_test_std,y_test)

# %%
y_pred_svm_reg=svm_reg.predict(x_test_std)
y_pred_svm_reg

# %%
result_svm_reg=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_svm_reg})
result_svm_reg

# %% [markdown]
# # **SVM MODEL EVALUATION**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
svm_reg_mse=mean_squared_error(y_test,y_pred_svm_reg)
svm_reg_mse

# %%
svm_reg_rmse=np.sqrt(svm_reg_mse)
svm_reg_rmse

# %%
svm_reg_r2=r2_score(y_test,y_pred_svm_reg)
svm_reg_r2

# %%
svm_reg_mae=mean_absolute_error(y_test,y_pred_svm_reg)
svm_reg_mae

# %% [markdown]
# # **PCA**

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
X_pca_train= pca.fit_transform(x_train_std)
X_pca_test=pca.transform(x_test_std)

# %% [markdown]
# # Training a model on PCA-transformed data

# %%
model=LinearRegression()

# %%
model.fit(X_pca_train,y_train)

# %%
model.score(X_pca_train,y_train)

# %%
model.score(X_pca_test, y_test)

# %%
y_pred_pca=model.predict(X_pca_test)

# %%
result_pca=pd.DataFrame({'PC1':y_test,'PC2':y_pred_pca})
result_pca
# actual and predicted.

# %% [markdown]
# Evaluating

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
pca_mse=mean_squared_error(y_test,y_pred_pca)
pca_mse

# %%
pca_rmse=np.sqrt(pca_mse)
pca_rmse

# %%
pca_r2=r2_score(y_test,y_pred_pca)
pca_r2

# %%
pca_mae=mean_absolute_error(y_test,y_pred_pca)
pca_mae
