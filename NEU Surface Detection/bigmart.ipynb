# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/bigmart.csv')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df['Item_Outlet_Sales'].max()
# Out:
# 13086.9648

# %%
df.sort_values('Item_Outlet_Sales',ascending=False)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7188           NCE42          NaN          Low Fat         0.010551
# 5223           FDQ19          NaN          Regular         0.014296
# 1450           FDZ20          NaN          Low Fat         0.000000
# 4349           FDP33          NaN          Low Fat         0.088840
# 6541           FDI50          NaN          Regular         0.030693
# ...              ...          ...              ...              ...
# 7388           FDQ47        7.155          Regular         0.281510
# 3053           NCL41          NaN          Low Fat         0.073077
# 2571           FDU21          NaN          Regular         0.134328
# 6950           NCR42        9.105          Low Fat         0.064411
# 906            DRK12        9.500          Low Fat         0.000000
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7188              Household  234.9958            OUT027
# ...

# %%
df['Item_Outlet_Sales'].min()
# Out:
# 33.29

# %%
df[:4]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# ...

# %%
df[3:8]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
# 7            Snack Foods  107.7622            OUT027
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# null value in item_weight and in outlet_size

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df['Item_Identifier'].value_counts()
# Out:
# Item_Identifier
# FDW13    10
# FDG33    10
# FDX31     9
# FDT07     9
# NCY18     9
#          ..
# FDO33     1
# FDK57     1
# FDT35     1
# FDN52     1
# FDE52     1
# Name: count, Length: 1559, dtype: int64

# %%
df['Item_Weight'].value_counts()
# Out:
# Item_Weight
# 12.150    86
# 17.600    82
# 13.650    77
# 11.800    76
# 15.100    68
#           ..
# 8.920      2
# 6.520      1
# 9.420      1
# 7.685      1
# 5.400      1
# Name: count, Length: 415, dtype: int64

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %% [markdown]
# need to replace item_fat_content

# %%
df[ 'Item_Visibility'].value_counts()
# Out:
# Item_Visibility
# 0.000000    526
# 0.076975      3
# 0.061271      2
# 0.046825      2
# 0.112399      2
#            ...
# 0.054142      1
# 0.018920      1
# 0.044974      1
# 0.103611      1
# 0.083060      1
# Name: count, Length: 7880, dtype: int64

# %%
df['Item_Type'].value_counts()
# Out:
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64

# %%
df['Item_MRP'].value_counts()
# Out:
# Item_MRP
# 172.0422    7
# 170.5422    6
# 142.0154    6
# 109.5228    6
# 188.1872    6
#            ..
# 108.7912    1
# 157.5972    1
# 245.2118    1
# 232.3326    1
# 39.6164     1
# Name: count, Length: 5938, dtype: int64

# %%
df[ 'Outlet_Identifier'].value_counts()
# Out:
# Outlet_Identifier
# OUT027    935
# OUT013    932
# OUT035    930
# OUT049    930
# OUT046    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: count, dtype: int64

# %%
df['Outlet_Establishment_Year'].value_counts()
# Out:
# Outlet_Establishment_Year
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: count, dtype: int64

# %%
df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# Outlet_Location_Type
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: count, dtype: int64

# %%
df[ 'Outlet_Type'].value_counts()
# Out:
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: count, dtype: int64

# %% [markdown]
# need to replace outlet_type

# %%
df['Item_Outlet_Sales'].value_counts()
# Out:
# Item_Outlet_Sales
# 958.7520     17
# 1342.2528    16
# 703.0848     15
# 1845.5976    15
# 1278.3360    14
#              ..
# 2224.4378     1
# 2419.5172     1
# 4111.3150     1
# 45.2744       1
# 6261.8490     1
# Name: count, Length: 3493, dtype: int64

# %%
df['Item_Weight'].fillna(df['Item_Weight'].mean(),inplace=True)
# Out:
# /tmp/ipython-input-3323749204.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Item_Weight'].fillna(df['Item_Weight'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0],inplace=True)
# Out:
# /tmp/ipython-input-1352639118.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# # **REPLACE UNWANTED VALUES**

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
df['Item_Fat_Content'].replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'},inplace=True)
# Out:
# /tmp/ipython-input-1952653531.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Item_Fat_Content'].replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'},inplace=True)

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
df['Outlet_Type'].value_counts()
# Out:
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: count, dtype: int64

# %%
df['Outlet_Type'].replace('Grocery Store','Supermarket Type4',inplace=True)
# Out:
# /tmp/ipython-input-3025160233.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Outlet_Type'].replace('Grocery Store','Supermarket Type4',inplace=True)

# %%
df['Outlet_Type'].value_counts()
# Out:
# Outlet_Type
# Supermarket Type1    5577
# Supermarket Type4    1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: count, dtype: int64

# %% [markdown]
# # **UNIVARIATE ANALYSIS**

# %% [markdown]
# (a)NUMERICAL

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df['Item_Weight'].hist(bins=5)
plt.xlabel('Item_Weight')
plt.ylabel('Frequency')
plt.title('Item_Weight Distribution')
plt.show()
df['Item_Weight'].describe()
# Out:
# count    8523.000000
# mean       12.857645
# std         4.226124
# min         4.555000
# 25%         9.310000
# 50%        12.857645
# 75%        16.000000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %% [markdown]
# Inference
#
#
# *   Item_Weight is distributed along x axis
# *   Frequency is distributed along y axis
# *   ---------
# *  ------------

# %%
df['Item_Visibility'].hist(bins=5)
plt.xlabel('Item_Visibility')
plt.ylabel('Frequency')
plt.title('Item_Visibility Distribution')
plt.show()
df['Item_Visibility'].describe()
# Out:
# count    8523.000000
# mean        0.066132
# std         0.051598
# min         0.000000
# 25%         0.026989
# 50%         0.053931
# 75%         0.094585
# max         0.328391
# Name: Item_Visibility, dtype: float64

# %% [markdown]
# INFERENCE
#
#
# *   Item_Visibility is distributed along x axis
# *   Frequency is distributed along y axis

# %%
df['Item_MRP'].hist(bins=5)
plt.xlabel('Item_MRP')
plt.ylabel('Frequency')
plt.title('Item_MRP Distribution')
plt.show()
df['Item_MRP'].describe()
# Out:
# count    8523.000000
# mean      140.992782
# std        62.275067
# min        31.290000
# 25%        93.826500
# 50%       143.012800
# 75%       185.643700
# max       266.888400
# Name: Item_MRP, dtype: float64

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df['Outlet_Establishment_Year'].hist(bins=5)
plt.xlabel('Outlet_Establishment_Year')
plt.ylabel('Frequency')
plt.title('Outlet_Establishment_Year Distribution')
plt.show()
df['Outlet_Establishment_Year'].describe()
# Out:
# count    8523.000000
# mean     1997.831867
# std         8.371760
# min      1985.000000
# 25%      1987.000000
# 50%      1999.000000
# 75%      2004.000000
# max      2009.000000
# Name: Outlet_Establishment_Year, dtype: float64

# %%
df['Item_Outlet_Sales'].hist(bins=5)
plt.xlabel('Item_Outlet_Sales')
plt.ylabel('Frequency')
plt.title('Item_Outlet_Sales Distribution')
plt.show()
df['Item_Outlet_Sales'].describe()
# Out:
# count     8523.000000
# mean      2181.288914
# std       1706.499616
# min         33.290000
# 25%        834.247400
# 50%       1794.331000
# 75%       3101.296400
# max      13086.964800
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# (b)CATEGORICAL

# %%
sns.countplot(x=df['Item_Identifier'])
plt.xlabel('Item_Identifier')
plt.ylabel('Frequency')
plt.title('Item_Identifier Distribution')
plt.show()

# %%
sns.countplot(x=df['Item_Fat_Content'])
plt.xlabel('Item_Fat_Content')
plt.ylabel('Frequency')
plt.title('Item_Fat_Content Distribution')
plt.show()

# %%
sns.countplot(x=df['Item_Type'])
plt.xlabel('Item_Type')
plt.ylabel('Frequency')
plt.title('Item_Type Distribution')
plt.xticks(rotation=90)  #---------------(used to avoid overwriting of labels along x axis)&(It provides control over the appearance and readability of the x-axis. )
plt.show()

# %%
sns.countplot(x=df['Outlet_Identifier'])
plt.xlabel('Outlet_Identifier')
plt.ylabel('Frequency')
plt.title('Outlet_Identifier Distribution')
plt.xticks(rotation=45)
plt.show()

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
sns.countplot(x=df['Outlet_Size'])
plt.xlabel('Outlet_Size')
plt.ylabel('Frequency')
plt.title('Outlet_Size Distribution')
plt.show()

# %%
sns.countplot(x=df['Outlet_Location_Type'])
plt.xlabel('Outlet_Location_Type')
plt.ylabel('Frequency')
plt.title('Outlet_Location_Type Distribution')
plt.show()

# %%
sns.countplot(x=df['Outlet_Type'])
plt.xlabel('Outlet_Type')
plt.ylabel('Frequency')
plt.title('Outlet_Type Distribution')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **BI-VARIATE ANALYSIS**

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
sns.barplot(x=df['Item_Fat_Content'],y=df['Item_Outlet_Sales'])
plt.xlabel('Item_Fat_Content')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
sns.barplot(x=df['Item_Type'],y=df['Item_Outlet_Sales'])
plt.xlabel('Item_Type')
plt.ylabel('Item_Outlet_Sales')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['Outlet_Identifier'],y=df['Item_Outlet_Sales'])
plt.xlabel('Outlet_Identifier')
plt.ylabel('Item_Outlet_Sales')
plt.xticks(rotation=90)
plt.show()

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
sns.barplot(x=df['Outlet_Size'],y=df['Item_Outlet_Sales'])
plt.xlabel('Outlet_Size')
plt.ylabel('Item_Outlet_Sales')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['Outlet_Location_Type'],y=df['Item_Outlet_Sales'])
plt.xlabel('Outlet_Location_Type')
plt.ylabel('Item_Outlet_Sales')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['Outlet_Type'],y=df['Item_Outlet_Sales'])
plt.xlabel('Outlet_Type')
plt.ylabel('Item_Outlet_Sales')
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df['Item_Weight'],y=df['Item_Outlet_Sales'])
plt.xlabel('Item_Weight')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
sns.scatterplot(x=df['Item_Visibility'],y=df['Item_Outlet_Sales'])
plt.xlabel('Item_Visibility')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
sns.scatterplot(x=df['Item_MRP'],y=df['Item_Outlet_Sales'])
plt.xlabel('Item_MRP')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
sns.barplot(x=df['Outlet_Establishment_Year'],y=df['Item_Outlet_Sales'])
plt.xlabel('Outlet_Establishment_Year')
plt.ylabel('Item_Outlet_Sales')
plt.show()

# %%
sns.scatterplot(x=df['Item_Weight'],y=df['Item_Visibility'])
plt.xlabel('Item_Weight')
plt.ylabel('Item_Visibility')
plt.show()

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
sns.scatterplot(x=df['Item_Weight'],y=df['Item_MRP'])
plt.xlabel('Item_Weight')
plt.ylabel('Item_MRP')
plt.show()

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
sns.barplot(x=df['Item_Fat_Content'],y=df['Item_Type'])
plt.xlabel('Item_Fat_Content')
plt.ylabel('Item_Type')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['Item_Fat_Content'],y=df['Item_MRP'])
plt.xlabel('Item_Fat_Content')
plt.ylabel('Item_MRP')
plt.show()

# %%
sns.barplot(x=df['Item_Type'],y=df['Item_Visibility'])
plt.xlabel('Item_Type')
plt.ylabel('Item_Visibility')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['Outlet_Type'],y=df['Outlet_Size'])
plt.xlabel('Outlet_Type')
plt.ylabel('Outlet_Size')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **MULTIVARIATE ANALYSIS**

# %%
# plt.figure(figsize=(20,10))
sns.barplot(data=df,x='Outlet_Establishment_Year',y='Item_Outlet_Sales',hue='Outlet_Type')
plt.title('Outlet_Establishment_Year vs Item_Outlet_Sales vs Outlet_Type')
plt.xticks(rotation=45)
plt.show()

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df,x='Item_Fat_Content',y='Item_Outlet_Sales',hue='Item_Type')
plt.title('Item_Fat_Content vs Item_Outlet_Sales vs Item_Type')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df,x='Item_Type',y='Item_Outlet_Sales',hue='Item_Fat_Content')
plt.title('Item_Fat_Content vs Item_Outlet_Sales vs Item_Type')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df,x='Item_Type',y='Item_Outlet_Sales',hue='Outlet_Size')
plt.title('Item_Fat_Content vs Item_Outlet_Sales vs Item_Type')
plt.xticks(rotation=45)
plt.show()

# %%
# plt.figure(figsize=(20,10))
sns.barplot(data=df,x='Outlet_Location_Type',y='Item_Outlet_Sales',hue='Outlet_Size')
plt.title('Outlet_Location_Type vs Item_Outlet_Sales vs Outlet_Size')
plt.xticks(rotation=45)
plt.show()

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
sns.barplot(data=df,x='Outlet_Size',y='Item_Outlet_Sales',hue='Outlet_Type')
plt.title('Outlet_Location_Type vs Item_Outlet_Sales vs Outlet_Size')
# plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **ENCODING**

# %% [markdown]
# **(a)Lablel Encoding**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
en=LabelEncoder()

# %%
df['Item_Fat_Content']=en.fit_transform(df['Item_Fat_Content'])
print(en.classes_)                       #(fit)-------eth label kodukanamennu check cheyyan use cheyunnu
# Out:
# ['Low Fat' 'Regular']

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# 0    5517
# 1    3006
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 0         0.016047
# 1           DRC01         5.92                 1         0.019278
# 2           FDN15        17.50                 0         0.016760
# 3           FDX07        19.20                 1         0.000000
# 4           NCD19         8.93                 0         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
en_outletsize=LabelEncoder()

# %%
df['Outlet_Size']=en_outletsize.fit_transform(df['Outlet_Size'])
print(en_outletsize.classes_)
# Out:
# ['High' 'Medium' 'Small']

# %%
df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# 1    5203
# 2    2388
# 0     932
# Name: count, dtype: int64

# %%
en_Outlet_Location_Type=LabelEncoder()

# %%
df['Outlet_Location_Type']=en_Outlet_Location_Type.fit_transform(df['Outlet_Location_Type'])
print(en_Outlet_Location_Type.classes_)
# Out:
# ['Tier 1' 'Tier 2' 'Tier 3']

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# Outlet_Location_Type
# 2    3350
# 1    2785
# 0    2388
# Name: count, dtype: int64

# %%
en_Outlet_Type=LabelEncoder()

# %%
df['Outlet_Type']=en_Outlet_Type.fit_transform(df['Outlet_Type'])
print(en_Outlet_Type.classes_)
# Out:
# ['Supermarket Type1' 'Supermarket Type2' 'Supermarket Type3'
#  'Supermarket Type4']

# %%
df['Outlet_Type'].value_counts()
# Out:
# Outlet_Type
# 0    5577
# 3    1083
# 2     935
# 1     928
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 0         0.016047
# 1           DRC01         5.92                 1         0.019278
# 2           FDN15        17.50                 0         0.016760
# 3           FDX07        19.20                 1         0.000000
# 4           NCD19         8.93                 0         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            1                     0            0
# 1                       2009            1                     2            1
# ...

# %% [markdown]
# **(b)Target Encoding**

# %%
pip install category_encoders
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 1.8 MB/s eta 0:00:00
# ...

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 0         0.016047
# 1           DRC01         5.92                 1         0.019278
# 2           FDN15        17.50                 0         0.016760
# 3           FDX07        19.20                 1         0.000000
# 4           NCD19         8.93                 0         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            1                     0            0
# 1                       2009            1                     2            1
# ...

# %%
from category_encoders import TargetEncoder

# %%
en_tar=TargetEncoder()

# %%
df['Outlet_Identifier']=en_tar.fit_transform(df['Outlet_Identifier'],df['Item_Outlet_Sales'])

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# Outlet_Identifier
# 3694.038558    935
# 2298.995256    932
# 2438.841866    930
# 2348.354635    930
# 2277.844267    930
# 2192.384798    929
# 1995.498739    928
# 2340.675263    926
# 339.351662     555
# 340.329723     528
# Name: count, dtype: int64

# %%
df['Item_Identifier']=en_tar.fit_transform(df['Item_Identifier'],df['Item_Outlet_Sales'])

# %%
df['Item_Identifier'].value_counts()
# Out:
# Item_Identifier
# 1985.870972    14
# 2081.162546    14
# 2324.993273    14
# 1954.806490    14
# 2509.299232    12
#                ..
# 2134.494085     1
# 1985.150478     1
# 2346.814956     1
# 2137.612629     1
# 2474.415381     1
# Name: count, Length: 1530, dtype: int64

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0      2879.598286         9.30                 0         0.016047
# 1      1920.354050         5.92                 1         0.019278
# 2      2030.685308        17.50                 0         0.016760
# 3      2347.410648        19.20                 1         0.000000
# 4      1879.152033         8.93                 0         0.000000
#
#                Item_Type  Item_MRP  Outlet_Identifier  \
# 0                  Dairy  249.8092        2348.354635
# 1            Soft Drinks   48.2692        1995.498739
# 2                   Meat  141.6180        2348.354635
# 3  Fruits and Vegetables  182.0950         339.351662
# 4              Household   53.8614        2298.995256
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            1                     0            0
# 1                       2009            1                     2            1
# ...

# %%
df['Item_Type']=en_tar.fit_transform(df['Item_Type'],df['Item_Outlet_Sales'])

# %%
df['Item_Type' ].value_counts()
# Out:
# Item_Type
# 2289.009592    1232
# 2277.321739    1200
# 2258.784300     910
# 2132.867744     856
# 2232.542597     682
# 2225.194904     649
# 1952.971207     648
# 2010.000265     520
# 2006.511735     445
# 2158.977911     425
# 2204.132226     251
# 2139.221623     214
# 1926.139788     169
# 2374.332240     148
# 2111.817224     110
# 2324.310010      64
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0      2879.598286         9.30                 0         0.016047
# 1      1920.354050         5.92                 1         0.019278
# 2      2030.685308        17.50                 0         0.016760
# 3      2347.410648        19.20                 1         0.000000
# 4      1879.152033         8.93                 0         0.000000
#
#      Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0  2232.542597  249.8092        2348.354635                       1999
# 1  2006.511735   48.2692        1995.498739                       2009
# 2  2158.977911  141.6180        2348.354635                       1999
# 3  2289.009592  182.0950         339.351662                       1998
# 4  2258.784300   53.8614        2298.995256                       1987
#
#    Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %% [markdown]
# # **OUTLIER HANDLING**

# %%
df.dtypes
# Out:
# Item_Identifier              float64
# Item_Weight                  float64
# Item_Fat_Content               int64
# Item_Visibility              float64
# Item_Type                    float64
# Item_MRP                     float64
# Outlet_Identifier            float64
# Outlet_Establishment_Year      int64
# Outlet_Size                    int64
# Outlet_Location_Type           int64
# Outlet_Type                    int64
# Item_Outlet_Sales            float64
# dtype: object

# %%
sns.boxplot(data=df,x="Item_Weight")
plt.title("Boxplot")
plt.show()

# %%
sns.boxplot(data=df,x="Item_Visibility")
plt.title("Boxplot")
plt.show()

# %%
Q1=df['Item_Visibility'].quantile(0.25)
Q3=df['Item_Visibility'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
df['Item_Visibility']=np.where(df['Item_Visibility']>upper_bound,upper_bound,
                        np.where(df['Item_Visibility']<lower_bound,lower_bound,df['Item_Visibility']))

# %%
sns.boxplot(data=df,x="Item_Visibility")
plt.title("Boxplot")
plt.show()

# %%
sns.boxplot(data=df,x="Item_MRP")
plt.title("Boxplot")
plt.show()

# %%
Q1=df['Item_MRP'].quantile(0.25)
Q3=df['Item_MRP'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
df['Item_MRP']=np.where(df['Item_MRP']>upper_bound,upper_bound,
                        np.where(df['Item_MRP']<lower_bound,lower_bound,df['Item_MRP']))

# %%
sns.boxplot(data=df,x="Item_MRP")
plt.title("Boxplot")
plt.show()

# %%
sns.boxplot(data=df,x="Outlet_Establishment_Year")
plt.title("Boxplot")
plt.show()

# %%
sns.boxplot(data=df,x="Item_Outlet_Sales")
plt.title("Boxplot")
plt.show()

# %% [markdown]
# # **CORRELATION**

# %%
df.corr()
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier                   1.000000     0.014604          0.032117
# Item_Weight                       0.014604     1.000000         -0.021157
# Item_Fat_Content                  0.032117    -0.021157          1.000000
# Item_Visibility                  -0.028822    -0.011928          0.049342
# Item_Type                         0.107370     0.045334          0.092989
# Item_MRP                          0.873031     0.024756          0.006063
# Outlet_Identifier                 0.072540    -0.001543          0.002336
# Outlet_Establishment_Year         0.001943    -0.008301          0.003151
# Outlet_Size                      -0.012360    -0.007225         -0.000622
# Outlet_Location_Type              0.012696     0.004088         -0.001598
# Outlet_Type                      -0.042915     0.002725         -0.001967
# Item_Outlet_Sales                 0.649101     0.011550          0.018719
#
# ...

# %%
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0         2879.598286        9.300                 0         0.016047
# 1         1920.354050        5.920                 1         0.019278
# 2         2030.685308       17.500                 0         0.016760
# 3         2347.410648       19.200                 1         0.000000
# 4         1879.152033        8.930                 0         0.000000
# ...               ...          ...               ...              ...
# 8518      2424.628001        6.865                 0         0.056783
# 8519      2271.350452        8.380                 1         0.046982
# 8520      1991.431370       10.600                 0         0.035186
# 8521      2158.829654        7.210                 1         0.145221
# 8522      2006.850542       14.800                 0         0.044878
#
#         Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
cor_df=["Item_Identifier","Item_MRP","Outlet_Identifier","Item_Outlet_Sales"]

# %%
df_cor=df[cor_df]

# %%
df_cor
# Out:
#       Item_Identifier  Item_MRP  Outlet_Identifier  Item_Outlet_Sales
# 0         2879.598286  249.8092        2348.354635          3735.1380
# 1         1920.354050   48.2692        1995.498739           443.4228
# 2         2030.685308  141.6180        2348.354635          2097.2700
# 3         2347.410648  182.0950         339.351662           732.3800
# 4         1879.152033   53.8614        2298.995256           994.7052
# ...               ...       ...                ...                ...
# 8518      2424.628001  214.5218        2298.995256          2778.3834
# 8519      2271.350452  108.1570        2192.384798           549.2850
# 8520      1991.431370   85.1224        2438.841866          1193.1136
# 8521      2158.829654  103.1332        1995.498739          1845.5976
# 8522      2006.850542   75.4670        2277.844267           765.6700
#
# [8523 rows x 4 columns]

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=df_cor.drop('Item_Outlet_Sales',axis=1)
y=df_cor['Item_Outlet_Sales']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#       Item_Identifier  Item_MRP  Outlet_Identifier
# 549       2131.917735  171.3448        2348.354635
# 7757      2205.928589  170.5422        2192.384798
# 764       2008.456470  111.7202        2277.844267
# 6867      1916.728028   41.6138        2192.384798
# 2716      2291.428777  155.5630        2277.844267
# ...               ...       ...                ...
# 5734      2115.755848  139.1838         339.351662
# 5191      1985.870972   75.6670        2340.675263
# 5390      2769.918146  237.3590        2192.384798
# 860       1977.335878  117.9466        2340.675263
# 7270      1947.134263   95.7410        2277.844267
#
# [6818 rows x 3 columns]

# %%
y_train
# Out:
# 549     2386.2272
# 7757    3103.9596
# 764     1125.2020
# 6867     284.2966
# 2716    4224.5010
#           ...
# 5734     280.9676
# 5191    1301.6390
# 5390    6145.3340
# 860     1649.8524
# 7270     965.4100
# Name: Item_Outlet_Sales, Length: 6818, dtype: float64

# %%
x_test
# Out:
#       Item_Identifier  Item_MRP  Outlet_Identifier
# 7503      1987.502142   79.4302        2298.995256
# 2957      1983.554723   42.7086        2277.844267
# 7031      1806.236752   42.0454        2348.354635
# 1084      2332.797683  173.7054        3694.038558
# 856       2110.740008  197.5110        2438.841866
# ...               ...       ...                ...
# 7205      2084.064567  127.1704        2277.844267
# 3257      2294.997013  148.1734        1995.498739
# 6346      1806.236752   42.0454        2298.995256
# 6318      1868.290213   50.5008        1995.498739
# 6339      2036.778019  109.2254        2192.384798
#
# [1705 rows x 3 columns]

# %%
y_test
# Out:
# 7503    1743.0644
# 2957     356.8688
# 7031     377.5086
# 1084    5778.4782
# 856     2356.9320
#           ...
# 7205    3004.0896
# 3257     890.8404
# 6346     629.1810
# 6318     253.0040
# 6339     976.7286
# Name: Item_Outlet_Sales, Length: 1705, dtype: float64

# %%
x_train.shape
# Out:
# (6818, 3)

# %%
y_train.shape
# Out:
# (6818,)

# %% [markdown]
# # **SCALING**

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train_std=scaler.fit_transform(x_train)
x_test_std=scaler.transform(x_test)

# %%
x_train_std
# Out:
# array([[-0.23399938,  0.47070929,  0.19403233],
#        [ 0.1022419 ,  0.45787656,  0.00788305],
#        [-0.79490053, -0.48262534,  0.10987853],
#        ...,
#        [ 2.66452239,  1.52620691,  0.00788305],
#        [-0.93628556, -0.38307175,  0.18486704],
#        [-1.07349557, -0.73811593,  0.10987853]])

# %%
x_test_std
# Out:
# array([[-0.89009886, -0.99890847,  0.13512214],
#        [-0.90803252, -1.58604822,  0.10987853],
#        [-1.71361193, -1.59665209,  0.19403233],
#        ...,
#        [-1.71361193, -1.59665209,  0.13512214],
#        [-1.4316947 , -1.46145914, -0.22709956],
#        [-0.66623192, -0.52251456,  0.00788305]])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mscaler=MinMaxScaler()

# %%
x_train_min=mscaler.fit_transform(x_train)
x_test_min=mscaler.transform(x_test)

# %%
x_train_min
# Out:
# array([[0.31270802, 0.59446414, 0.59886452],
#        [0.37801845, 0.59105749, 0.55237141],
#        [0.20376037, 0.34138687, 0.57784606],
#        ...,
#        [0.87570764, 0.87466214, 0.55237141],
#        [0.17629819, 0.36781489, 0.59657538],
#        [0.14964696, 0.27356298, 0.57784606]])

# %%
x_test_min
# Out:
# array([[0.18526935, 0.20433161, 0.58415097],
#        [0.18178597, 0.04846637, 0.57784606],
#        [0.0253128 , 0.04565141, 0.59886452],
#        ...,
#        [0.0253128 , 0.04565141, 0.58415097],
#        [0.0800715 , 0.08154045, 0.49368157],
#        [0.22875255, 0.33079766, 0.55237141]])

# %% [markdown]
# # **MODEL BUILDING**

# %% [markdown]
# # **Hyperparameter Tuning**

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.metrics import r2_score



# Step 3: Define models
models = {
    'KNN Regressor': KNeighborsRegressor(),
    'Linear Regression': LinearRegression(),
    'Decision Tree Regressor': DecisionTreeRegressor(random_state=42),
    'Random Forest Regressor': RandomForestRegressor(random_state=42),
    'AdaBoost Regressor': AdaBoostRegressor(random_state=42)
}

# Step 4: Define parameter grids for each model
param_grids = {
    'KNN Regressor': {
        'n_neighbors': [3, 5, 7, 9],
        'weights': ['uniform', 'distance'],
        'p': [1, 2]
    },
    'Linear Regression': {
        'fit_intercept': [True, False],
        'copy_X': [True, False]
    },
    'Decision Tree Regressor': {
        'criterion': ['squared_error', 'friedman_mse'],
        'max_depth': [None, 5, 10, 20],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    },
    'Random Forest Regressor': {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'bootstrap': [True, False]
    },
    'AdaBoost Regressor': {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 1.0]
    }
}

# Step 5: Perform Grid Search for each model
best_models = {}

for name, model in models.items():
    print(f"\n🔍 Tuning {name}...")

    grid = GridSearchCV(
        estimator=model,
        param_grid=param_grids[name],
        cv=5,
        scoring='r2',
        n_jobs=-1
    )

    grid.fit(x_train_min,y_train)
    best_models[name] = grid.best_estimator_

    print(f"✅ Best Parameters for {name}: {grid.best_params_}")
    print(f"🏆 Best R² Score (CV): {grid.best_score_:.4f}")

# Step 6: Evaluate the best models on test data
print("\n📊 Final Model Performance on Test Set:")
for name, model in best_models.items():
    y_pred = model.predict(x_test_min)
    print(f"{name}: R² Score = {r2_score(y_test, y_pred):.4f}")
# Out:
# 🔍 Tuning KNN Regressor...
# ✅ Best Parameters for KNN Regressor: {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 🏆 Best R² Score (CV): 0.6321
#
# 🔍 Tuning Linear Regression...
# ✅ Best Parameters for Linear Regression: {'copy_X': True, 'fit_intercept': True}
# 🏆 Best R² Score (CV): 0.6219
#
# 🔍 Tuning Decision Tree Regressor...
# ✅ Best Parameters for Decision Tree Regressor: {'criterion': 'squared_error', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 🏆 Best R² Score (CV): 0.6450
#
# 🔍 Tuning Random Forest Regressor...
# ✅ Best Parameters for Random Forest Regressor: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200}
# 🏆 Best R² Score (CV): 0.6494
#
# 🔍 Tuning AdaBoost Regressor...
# ✅ Best Parameters for AdaBoost Regressor: {'learning_rate': 0.1, 'n_estimators': 50}
# 🏆 Best R² Score (CV): 0.6332
#
# 📊 Final Model Performance on Test Set:
# KNN Regressor: R² Score = 0.6305
# ...

# %% [markdown]
# # **KNN**

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knnr=KNeighborsRegressor(n_neighbors=7)

# %%
knnr.fit(x_train_min,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %%
knnr.score(x_train_min,y_train)
# Out:
# 0.7133041691844061

# %%
knnr.score(x_test_min,y_test)
# Out:
# 0.6238864518813698

# %%
y_pred_knn=knnr.predict(x_test_min)
y_pred_knn
# Out:
# array([1451.06354286, 1086.68071429,  578.48508571, ...,  562.22054286,
#         565.16908571, 1214.60942857])

# %%
result_knn=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_knn})
result_knn
# Out:
#          Actual    Predicted
# 7503  1743.0644  1451.063543
# 2957   356.8688  1086.680714
# 7031   377.5086   578.485086
# 1084  5778.4782  4882.311400
# 856   2356.9320  2455.089943
# ...         ...          ...
# 7205  3004.0896  1869.281057
# 3257   890.8404  2049.903086
# 6346   629.1810   562.220543
# 6318   253.0040   565.169086
# 6339   976.7286  1214.609429
#
# [1705 rows x 2 columns]

# %%
sns.lineplot(data=result_knn)
plt.title('KNN')
plt.show()

# %% [markdown]
# # **KNN MODEL EVALUATION**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
knn_mse=mean_squared_error(y_test,y_pred_knn)
knn_mse
# Out:
# 1022265.3654354451

# %%
knn_rmse=np.sqrt(knn_mse)
knn_rmse
# Out:
# np.float64(1011.0713948260257)

# %%
knn_mae=mean_absolute_error(y_test,y_pred_knn)
knn_mae
# Out:
# 707.1016910599078

# %%
knn_r2=r2_score(y_test,y_pred_knn)
knn_r2
# Out:
# 0.6238864518813698

# %% [markdown]
# # **LINEAR REGRESSION MODEL**

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train_std,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train_std,y_train)
# Out:
# 0.6225968681342036

# %%
lr.score(x_test_std,y_test)
# Out:
# 0.6224270380952166

# %%
y_pred_lr=lr.predict(x_test_std)
y_pred_lr
# Out:
# array([1312.64664956, 1161.64748255,  502.32268321, ...,  456.6194179 ,
#         455.01223887, 1508.29728169])

# %%
result_lr=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_lr})
result_lr
# Out:
#          Actual    Predicted
# 7503  1743.0644  1312.646650
# 2957   356.8688  1161.647483
# 7031   377.5086   502.322683
# 1084  5778.4782  4307.442593
# 856   2356.9320  2315.151867
# ...         ...          ...
# 7205  3004.0896  1836.467478
# 3257   890.8404  2500.499584
# 6346   629.1810   456.619418
# 6318   253.0040   455.012239
# 6339   976.7286  1508.297282
#
# [1705 rows x 2 columns]

# %%
sns.lineplot(data=result_lr)
plt.title('KNN')
plt.show()

# %% [markdown]
# # **LINEAR MODEL EVALUATION**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error,root_mean_squared_error

# %%
lr_mse=mean_squared_error(y_test,y_pred_lr)
lr_mse
# Out:
# 1026232.0084210171

# %%
lr_rmse=np.sqrt(lr_mse)
lr_rmse
# Out:
# np.float64(1013.0310994342756)

# %%
lr_mae=mean_absolute_error(y_test,y_pred_lr)
lr_mae
# Out:
# 749.3607782787446

# %%
lr_r2=r2_score(y_test,y_pred_lr)
lr_r2
# Out:
# 0.6224270380952166

# %% [markdown]
# # **DECISION TREE ALGORITHM**

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
deci = DecisionTreeRegressor(
    criterion='squared_error',       # 'gini' (default) or 'entropy'
    splitter='best',           # 'best' or 'random'
    max_depth=5,               # limit depth to avoid overfitting
    min_samples_split=4,       # minimum samples needed to split a node
    min_samples_leaf=2,        # minimum samples in each leaf node
    max_features=None,         # number of features to consider for best split
    random_state=42,           # ensures reproducibility
    max_leaf_nodes=None,       # maximum number of leaf nodes
    ccp_alpha=0.0              # pruning parameter (larger value → simpler tree)
)

# %%
deci.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_leaf=2, min_samples_split=4,
#                       random_state=42)

# %%
deci.score(x_train,y_train)
# Out:
# 0.66285105668432

# %%
deci.score(x_test,y_test)
# Out:
# 0.6406452764464461

# %%
y_pred_deci=deci.predict(x_test)
y_pred_deci
# Out:
# array([1271.04628896, 1271.04628896,  749.02672041, ...,  749.02672041,
#         749.02672041, 1708.24785112])

# %%
result_deci=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_deci})
result_deci
# Out:
#          Actual    Predicted
# 7503  1743.0644  1271.046289
# 2957   356.8688  1271.046289
# 7031   377.5086   749.026720
# 1084  5778.4782  4595.052248
# 856   2356.9320  1708.247851
# ...         ...          ...
# 7205  3004.0896  1708.247851
# 3257   890.8404  2914.510622
# 6346   629.1810   749.026720
# 6318   253.0040   749.026720
# 6339   976.7286  1708.247851
#
# [1705 rows x 2 columns]

# %% [markdown]
# # **DECISION TREE MODEL EVALUATION**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error,root_mean_squared_error

# %%
deci_mse=mean_squared_error(y_test,y_pred_deci)
deci_mse
# Out:
# 976715.3819158868

# %%
deci_rmse=np.sqrt(deci_mse)
deci_rmse
# Out:
# np.float64(988.2891185861994)

# %%
deci_mae=mean_absolute_error(y_test,y_pred_deci)
deci_mae
# Out:
# 686.4546755026201

# %%
deci_r2=r2_score(y_test,y_pred_deci)
deci_r2
# Out:
# 0.6406452764464461

# %%
deci_mae=mean_absolute_error(y_test,y_pred_deci)
deci_mae
# Out:
# 686.4546755026201

# %% [markdown]
# # **RANDOM FOREST MODEL**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rand=RandomForestRegressor(n_estimators=50,max_depth=5)

# %%
rand.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=50)

# %%
rand.score(x_train,y_train)
# Out:
# 0.6718765842855499

# %%
rand.score(x_test,y_test)
# Out:
# 0.6547538848382388

# %%
y_pred_rand=rand.predict(x_test)
y_pred_rand
# Out:
# array([1276.44479709, 1117.4912553 ,  727.31667752, ...,  727.31667752,
#         733.11594692, 1501.0762082 ])

# %%
result=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_rand})
result
# Out:
#          Actual    Predicted
# 7503  1743.0644  1276.444797
# 2957   356.8688  1117.491255
# 7031   377.5086   727.316678
# 1084  5778.4782  4707.085182
# 856   2356.9320  2038.208199
# ...         ...          ...
# 7205  3004.0896  1784.227260
# 3257   890.8404  2838.736000
# 6346   629.1810   727.316678
# 6318   253.0040   733.115947
# 6339   976.7286  1501.076208
#
# [1705 rows x 2 columns]

# %% [markdown]
# # **RANDOM FOREST MODEL EVALUATION**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error,root_mean_squared_error

# %%
rand_mse=mean_squared_error(y_test,y_pred_rand)
rand_mse
# Out:
# 938368.6066253765

# %%
rand_rmse=np.sqrt(rand_mse)
rand_rmse
# Out:
# np.float64(968.6942792364248)

# %%
rand_r2=r2_score(y_test,y_pred_rand)
rand_r2
# Out:
# 0.6547538848382388

# %%
rand_mae=mean_absolute_error(y_test,y_pred_rand)
rand_mae
# Out:
# 674.361275869751

# %% [markdown]
# # **BOOSTING MODEL**

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
base_model = DecisionTreeRegressor(max_depth=3)
boost= AdaBoostRegressor(estimator=base_model,n_estimators=100,learning_rate=0.1,random_state=42)

# %%
boost.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3),
#                   learning_rate=0.1, n_estimators=100, random_state=42)

# %%
boost.score(x_train,y_train)
# Out:
# 0.6245549392315183

# %%
boost.score(x_test,y_test)
# Out:
# 0.5906300851172102

# %%
y_pred_boost=boost.predict(x_test)
y_pred_boost
# Out:
# array([1221.11649031, 1221.11649031, 1091.28572237, ..., 1091.28572237,
#        1087.10111331, 1549.01714556])

# %%
result_boost=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_boost})
result_boost
# Out:
#          Actual    Predicted
# 7503  1743.0644  1221.116490
# 2957   356.8688  1221.116490
# 7031   377.5086  1091.285722
# 1084  5778.4782  4750.663931
# 856   2356.9320  2155.184846
# ...         ...          ...
# 7205  3004.0896  1939.169562
# 3257   890.8404  2954.808029
# 6346   629.1810  1091.285722
# 6318   253.0040  1087.101113
# 6339   976.7286  1549.017146
#
# [1705 rows x 2 columns]

# %% [markdown]
# # **BOOSTING MODEL EVALUATION**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error,root_mean_squared_error

# %%
boost_mse=mean_squared_error(y_test,y_pred_boost)
boost_mse
# Out:
# 1112655.174824858

# %%
boost_rmse=np.sqrt(boost_mse)
boost_rmse
# Out:
# np.float64(1054.8247128432563)

# %%
boost_r2=r2_score(y_test,y_pred_boost)
boost_r2
# Out:
# 0.5906300851172102

# %%
boost_mae=mean_absolute_error(y_test,y_pred_boost)
boost_mae
# Out:
# 808.2070995626457

# %% [markdown]
# # **STACKING AGORITHM MODEL**

# %%
from sklearn.ensemble import StackingRegressor

# %%
st=StackingRegressor(estimators=[('knn',knnr),('lr',lr),('deci',deci),('rand',rand),('boost',boost)],final_estimator=LinearRegression())

# %%
st.fit(x_train_std,y_train)
# Out:
# StackingRegressor(estimators=[('knn', KNeighborsRegressor(n_neighbors=7)),
#                               ('lr', LinearRegression()),
#                               ('deci',
#                                DecisionTreeRegressor(max_depth=5,
#                                                      min_samples_leaf=2,
#                                                      min_samples_split=4,
#                                                      random_state=42)),
#                               ('rand',
#                                RandomForestRegressor(max_depth=5,
#                                                      n_estimators=50)),
#                               ('boost',
#                                AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3),
#                                                  learning_rate=0.1,
#                                                  n_estimators=100,
# ...

# %%
st.score(x_train_std,y_train)
# Out:
# 0.6753635910760095

# %%
st.score(x_test_std,y_test)
# Out:
# 0.6598988235521492

# %%
y_pred_st=st.predict(x_test_std)
y_pred_st
# Out:
# array([1239.10841488, 1055.59862971,  644.2078098 , ...,  635.21707345,
#         646.37286565, 1379.68254862])

# %%
result_st=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_st})
result_st
# Out:
#          Actual    Predicted
# 7503  1743.0644  1239.108415
# 2957   356.8688  1055.598630
# 7031   377.5086   644.207810
# 1084  5778.4782  4727.224261
# 856   2356.9320  2193.047249
# ...         ...          ...
# 7205  3004.0896  1794.705953
# 3257   890.8404  2739.897583
# 6346   629.1810   635.217073
# 6318   253.0040   646.372866
# 6339   976.7286  1379.682549
#
# [1705 rows x 2 columns]

# %% [markdown]
# # **STACKING ALGORITHM MODEL**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error,root_mean_squared_error

# %%
st_mse=mean_squared_error(y_test,y_pred_st)
st_mse
# Out:
# 924384.8172063907

# %%
st_rmse=np.sqrt(st_mse)
st_rmse
# Out:
# np.float64(961.4493315855967)

# %%
st_r2=r2_score(y_test,y_pred_st)
st_r2
# Out:
# 0.6598988235521492

# %%
st_mae=mean_absolute_error(y_test,y_pred_st)
st_mae
# Out:
# 678.7639125133346

# %% [markdown]
# # **SVM ALGORITHM**

# %%
from sklearn.svm import SVR

# %%
svm_rg=SVR(kernel='linear',C=1.0,epsilon=0.1)

# %%
svm_rg.fit(x_train_std,y_train)
# Out:
# SVR(kernel='linear')

# %%
svm_rg.score(x_train_std,y_train)
# Out:
# 0.5906726773740811

# %%
svm_rg.score(x_test_std,y_test)
# Out:
# 0.6026606772634183

# %%
y_pred_svm_rg=svm_rg.predict(x_test_std)
y_pred_svm_rg
# Out:
# array([1280.87318738, 1062.9576979 ,  625.53176679, ...,  590.09291615,
#         585.96869022, 1494.73116142])

# %%
result_svm_rg=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_svm_rg})
result_svm_rg
# Out:
#          Actual    Predicted
# 7503  1743.0644  1280.873187
# 2957   356.8688  1062.957698
# 7031   377.5086   625.531767
# 1084  5778.4782  3718.894717
# 856   2356.9320  2335.272935
# ...         ...          ...
# 7205  3004.0896  1779.113825
# 3257   890.8404  2262.625716
# 6346   629.1810   590.092916
# 6318   253.0040   585.968690
# 6339   976.7286  1494.731161
#
# [1705 rows x 2 columns]

# %% [markdown]
# # **SVM MODEL EVALUATION**

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
svm_rg_mse=mean_squared_error(y_test,y_pred_svm_rg)
svm_rg_mse
# Out:
# 1079956.3854877902

# %%
svm_rg_rmse=np.sqrt(svm_rg_mse)
svm_rg_rmse
# Out:
# np.float64(1039.2095002874976)

# %%
svm_rg_r2=r2_score(y_test,y_pred_svm_rg)
svm_rg_r2
# Out:
# 0.6026606772634183

# %%
svm_rg_mae=mean_absolute_error(y_test,y_pred_svm_rg)
svm_rg_mae
# Out:
# 746.0607911161753

# %% [markdown]
# # **PCA**

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
X_pca_train= pca.fit_transform(x_train_std)
X_pca_test=pca.transform(x_test_std)

# %% [markdown]
# # Training a model on PCA-transformed data

# %%
model=LinearRegression()

# %%
model.fit(X_pca_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_pca_train,y_train)
# Out:
# 0.6139806587475609

# %%
model.score(X_pca_test,y_test)
# Out:
# 0.6206946348413864

# %%
y_pred_pca=model.predict(X_pca_test)
y_pred_pca
# Out:
# array([1282.53721786,  950.42652475,  546.09458645, ...,  498.82812658,
#         440.83885685, 1554.66966043])

# %%
result_pca=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_pca})
result_pca
# Out:
#          Actual    Predicted
# 7503  1743.0644  1282.537218
# 2957   356.8688   950.426525
# 7031   377.5086   546.094586
# 1084  5778.4782  4300.647093
# 856   2356.9320  2710.020892
# ...         ...          ...
# 7205  3004.0896  1908.208693
# 3257   890.8404  2365.089116
# 6346   629.1810   498.828127
# 6318   253.0040   440.838857
# 6339   976.7286  1554.669660
#
# [1705 rows x 2 columns]

# %% [markdown]
# Evaluating

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
pca_mse=mean_squared_error(y_test,y_pred_pca)
pca_mse
# Out:
# 1030940.628608237

# %%
pca_rmse=np.sqrt(pca_mse)
pca_rmse
# Out:
# np.float64(1015.3524652101048)

# %%
pca_r2=r2_score(y_test,y_pred_pca)
pca_r2
# Out:
# 0.6206946348413864

# %%
pca_mae=mean_absolute_error(y_test,y_pred_pca)
pca_mae
# Out:
# 751.9130368017271
